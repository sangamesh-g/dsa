# %%
for i in range(5):
    for j in range(5):
        print("*",end="")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(5):
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****

# %%
for i in range(5):
    for j in range(i):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444

# %%
for i in range(5):
    for j in range(i):
        print("*",end="")
    print()
for i in range(5):
    for j in range(5-i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(5):
    k=4
    print(" "*(k-i),end="")
    print("* "*i,end="")
    print()
# Out:
#
#    *
#   * *
#  * * *
# * * * *

# %%
for i in range(5):
    k=5
    print(" "*(k-i),end="")
    print("* "*i)
for i in range(4,0,-1):
    k=5
    print(" "*(k-i),end="")
    print("* "*i)
# Out:
#
#     *
#    * *
#   * * *
#  * * * *
#  * * * *
#   * * *
#    * *
#     *
